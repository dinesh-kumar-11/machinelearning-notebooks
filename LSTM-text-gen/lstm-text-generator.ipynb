# %%
import tensorflow.keras as keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 3s 5us/step
# Corpus length: 600893

# %%
max_len = 60
steps = 3

# %%
sentences = []
next_chars = []

for i in range(0, len(text)-max_len, steps):
    sentences.append(text[i:i+max_len])
    next_chars.append(text[i+max_len])

# %%
print("The number of sequences is,", len(sentences))
# Out:
# The number of sequences is, 200278

# %%
chars = sorted(list(set(text)))

# %%
print('Unique chars:', len(chars))
# Out:
# Unique chars: 57

# %%
char_indices = dict((char, chars.index(char)) for char in chars)

# %%
print('Vectorization...')
x = np.zeros((len(sentences), max_len, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(max_len, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
# Given a trained model and a seed text snippet, you can generate new text by doing the following repeatedly:
#
# * Draw from the model a probability distribution for the next character, given the generated text available so far.
# * Reweight the distribution to a certain temperature.
# * Sample the next character at random according to the reweighted distribution.
# * Add the new character at the end of the available text.
#
# This is the code you use to reweight the original probability distribution coming out of the model and draw a character index from it (the sampling function).

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - max_len - 1)
    generated_text = text[start_index: start_index + max_len]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        for i in range(400):
            sampled = np.zeros((1, max_len, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 153s 98ms/step - loss: 1.6175
# --- Generating with seed: "r lie in
# a lonely moor? it is impossible to think of mortal "
# ------ temperature: 0.2
# r lie in
# a lonely moor? it is impossible to think of mortal and all strange the soul the spirits of the soul the sense and also the such and them and more and the strength and the most condection of the condection of the sout the enders of the strange the self and self and self-personal and the self and the delight and like the strange of the strange the condection of the strange the strength the same the same the spirit and also is are the present--in the------ temperature: 0.5
# same the same the spirit and also is are the present--in the most does be as one of
# the pholosophy and self-and spirit. that it is to the same and in which which is the such the soul,
# and
# which he is not one word and south them the spirit that that which has the good
# the spirit and life of delight one higher and the fact them and all and strange to the one does not present she every and disporition in instance, and soul theres a really delight and responsi------ temperature: 1.0
# n in instance, and soul theres a really delight and responsise the by incencioual one  through before instance wfith we len
# finglaithortw, no love one heal--to lirered, on which. gravs the mosmionational agticefully are the
# uncon that ctution of this patist inploweing to the selugation and quemorfing menteruge, grorgical bundulentaring be there admangs--even of dreaisory
# of chilld, in
# these
# pains.
#
#
# 1
# 1
# individualosared and nis , doti to preself--individue------ temperature: 1.2
#
#
#
# 1
# 1
# individualosared and nis , doti to preself--individuely who does ething, one world," good"o
# in them ciwsedfativeued above worls ached alsoodyance, as divalizing.
# our sentimatedm respected of
# the natues of crumaning (or nolbrood
# throughess; thure thinking one
# whereeant of silffutiohion thereby any seainw.
#
# tlole
# signifi,
# faol will. thuice ageomen kreather
# just! histour himse-fewly is the sucvely, to he and had fool, on
# groatians., are 2braths man.
#
# epoch 2
# 1565/1565 [==============================] - 150s 96ms/step - loss: 1.5282
# --- Generating with seed: "the old false adornment, frippery, and
# gold-dust of unconsci"
# ------ temperature: 0.2
# the old false adornment, frippery, and
# gold-dust of unconscience the self and the self-reason the self deal the self and in the emotions of the fact the self-respect to the science is and the self-superation of the self seem of the self seem of the present not the religious and and the self something and and the self-superation of the self seems and in the self-reason to the self desires of the sense of the self-superality of the self-reason of the sense o------ temperature: 0.5
# nse of the self-superality of the self-reason of the sense of seems the emotion of beer to pleasen, as more this ecseative the world something in the present in its like considerated to be fait the intimation of the like or interestion to learns to disclose the sace of the present and will more freedoms the properational and the higher and the intimate consideration. and what a considerately
# prolonser and his effect to intimelt and stand the superficiation------ temperature: 1.0
# nser and his effect to intimelt and stand the superficiation with that instands which the
# intimitious oprans
# and charment and upin our geveloe, do man of ppirclity i ineloor the very promes
# . by off. a just devetessentent read, and is ears man sictive supposing ones: howevever, sympreses ligh delight. the wholizes in our enteramiation of the claft and spirit to phyper to spies free hspind nainoly taint after, it is bieds englons--the matter.
#
# jus
# meand lis------ temperature: 1.2
# taint after, it is bieds englons--the matter.
#
# jus
# meand lis in uponded tygaitic flet
# not plaseable, are higher europe kx-texe thut does more after. i blekeved)ness dief, eve; admitedy man urio-consac--worth. or malites to a
# misunder dibles upon which that in follos--indefundhing mexaps, man indyprespately undendest yateromed indidutenestain, no undarparico nonrevally houss
# now:
# every
# unclues! even
#
# epe- cin toow in those revencely haften itself se
# figr peepoch 3
# 1565/1565 [==============================] - 146s 93ms/step - loss: 1.4811
# --- Generating with seed: "tist, one finds a very
# remarkable man.
#
# 138. we do the same "
# ------ temperature: 0.2
# tist, one finds a very
# remarkable man.
#
# 138. we do the same the world of the standing and the suffers to the most possibility of the same the something and and and modern and the subject of the something to the soul and surmelt and something and something and modern and more conduct of the world of the surmed and and all the sense of an action of the self-conceited and and modern in the self-contradiction of the something and power and and rest of the sent------ temperature: 0.5
# adiction of the something and power and and rest of the sentiment of the most difficulty; that is growtness of the power--is in people himself the power--or and the soul the conditions of the most deep to any, and possibility of the
# case, and man
# has not been the entire in the stronger and such an antillens and something be end and modest person of a man and man who pates former and the same the sensible expering conditions of the self-escent persisted fro------ temperature: 1.0
# ensible expering conditions of the self-escent persisted from consideration of firspristumy and good amous a sense and most
# priled hard condiciations, condfurdness
# of
# view
# execuaniti.
#
# sun crastilest formising in beromes (understathing stic abone, enslimation to tattoor imptioned end doncive rendepow? in not we always infingothing to a sur, and, and another,
# our conscience as least, aveolog, forms our innocenced--for an pottlectureness result and into dead------ temperature: 1.2
#  our innocenced--for an pottlectureness result and into dead.rmunitm amores not chatabler hos
# greatical modelty if
# turn upon, and mounal sainant a inagenesones--emotion the kepievative and
# whing woraghy
# terrible of immegman sentious, most digninal
# her, plannns
# blast,snessed--agh welled,
# and are is divitating. but ver many.=--but before arispowed of
# hentingmenth--any
# a dangered, to
# metamen light
# perusible
# up encoughrs
#
# undmoying bold have to "catives
# time wepoch 4
# 1565/1565 [==============================] - 146s 93ms/step - loss: 1.4500
# --- Generating with seed: " mistaken knowledge!) as an instrument. but whoever
# consider"
# ------ temperature: 0.2
#  mistaken knowledge!) as an instrument. but whoever
# considered and the forming to the forming the present the former the present of the present with the forming of the sense of the former the forming to the formully and the probably the for the forming the former and desire of the forming to be and also and the hand in the probably and the for the most more intelligence of the sense of the former the forming to probably and desires and the soul the sense o------ temperature: 0.5
# the forming to probably and desires and the soul the sense of the world desinting and will be one condition to be strong, one should perhaps the latter of some for the and intellsct, become one man have the most feeling the confeming of the sense
# on the from the hand, in the powerful in the one before his also been and a stander--our from the feeling the further to them in the good so sort of the factation of any shown every constituter the first himself i------ temperature: 1.0
# factation of any shown every constituter the first himself in historyfulnesspy, asdant in such
# prolon to launh. thous
# ceriess"." the doow was all the trust
# and bedon the
# for which a
# manifest withers
# manvifutical hatder
# and so
# would we has
# not utder from our strengre stifues, to good were and powsables, for instinct, undersismed for great german, ;takes
# a selsceable includence, us also according of the worth ser unthing our pointing wishes its sur; onous fa------ temperature: 1.2
#  the worth ser unthing our pointing wishes its sur; onous facher intextre han is
# expesioned,
# dittyines--langurant, but lebty, is generals in
# ital wholit--
#
# yhe germent oful allow the mame rank in the
# stitnoned tegropion, he have quescoin; for ye clust(amouslen morever without specity--it is trieed--a bode is pect is long: he
# sivlined in old, the believer bad
# gottnedly, the good continued indeed better predoo--seevobly delicatectsific firnt more spitihlosedepoch 5
# 1565/1565 [==============================] - 152s 97ms/step - loss: 1.4292
# --- Generating with seed: "e will there is
# a ruling thought;--and let us not imagine it"
# ------ temperature: 0.2
# e will there is
# a ruling thought;--and let us not imagine it is the strength in the strength of the precisely be a strength in the same the spring of the strength of the strength of the strength of the sense of the strength of the strength of the sense of the strength of the strength in the spiritse of the sense of the spiritse of the strength of the strength of the sense of the strength in the same the present and contempted the spiritse of the spiritse o------ temperature: 0.5
# me the present and contempted the spiritse of the spiritse of the sense of the scortes, and the mome of the development of pleasure is also every period be an inclore and such an end and and cruel of the principal far of the same morality of the spring of the feeling religion for the intellection of the strength of the later, and where in the same the sense of the feelings and moralists of the good taste of the own present mental and proounce when least th------ temperature: 1.0
# d taste of the own present mental and proounce when least the regarding to the schopenhauer. intolatience of the period called their will that whate will always in the cylante of understandarians: in ne de over mores, our geet keept every obslictions, untermain intellect cill healingly to stappoble streflow of but who
# concaal the sxus master, to little ferit that is
# clasite a conscious an intruodment whate we
# does not be bet
# referents of manitent, of yeus ------ temperature: 1.2
# ent whate we
# does not be bet
# referents of manitent, of yeus geith in whish remeal arish, not nwere latteriness
# ustay he enliepors
# egoical stage strengchelle. pricisistion
# or whether not inevelority, the stood exul them. regye overestive the "freershad occord! betrayeepts offell usorder, sport of per-vaiceh soul it may, the dediveraterle acc-possigntible, becomen accordance-instance of lights enoried that savages because but fj;ed what use orvew, who detairepoch 6
# 1565/1565 [==============================] - 145s 92ms/step - loss: 1.4117
# --- Generating with seed: "facts" a new anchorage and above
# all a new calling were to b"
# ------ temperature: 0.2
# facts" a new anchorage and above
# all a new calling were to be the free spiritual and man is the interests of the fundamental and the fact that the deceive and all the same the free spiritual and the spiritual and the greatest and the fact of the free spiritual and the same the spiritual and the conscience of the spiritual men, and the ancional possible the superstion of the form of the faculty of the fundamental entire and the faculty and the means of the ------ temperature: 0.5
# the fundamental entire and the faculty and the means of the means of the more the such an and determine that the wild the action that perhaps is to be all the value and belief. in the conceited the present the fact in the faculty which his man they not for the sense of a distonment and supersers of the banding of the faculty of the words that the feeling of the possible of a possible" it thinks there would be new explanity them has one of the german concer------ temperature: 1.0
# ere would be new explanity them has one of the german concerning, and called doubt and that he
# tough then it suffer, is possess them) their can concerning from mensch and made this acpetions of all the beliof and rary in the excess would be wild he is discondect. false mightly
# back of
# the fundamental humanistal, dare, perhaps doly tobage it to caul desires, and "astems wholly be a pi-nowing of the mew"
# they often he say.
#
# 1e1. evex drage and love
# makes und------ temperature: 1.2
#  mew"
# they often he say.
#
# 1e1. evex drage and love
# makes under bod. _marner
# velity as a symptors, and edacremeab redeject has no recig? what, the ef hoe hy through ixestance, and just and at his at
# this perishedness.
#
# thet he greef? conducary when life,"
# have reauch and originates wockinessy, inegumetany in heageain longing man then secor thereby not beyord sublic to sogian listeen rovica
# difficultment about god, sextered dnection. thus of
# teach aw: the thepoch 7
# 1565/1565 [==============================] - 156s 99ms/step - loss: 1.3989
# --- Generating with seed: " the other is out of the question. thus is left
# quite ignore"
# ------ temperature: 0.2
#  the other is out of the question. thus is left
# quite ignore of the spect of the same and the spirit of the same and the later of the fact of the actions of the former and the same and the charms of the most and the presentially and the spect of the same to the fact of the morality of the fact of the fact of the fact of the most can be the same and the standard and the has of the really and for the fact of the fact of the manifests of the most cannot for t------ temperature: 0.5
# e fact of the fact of the manifests of the most cannot for the present, and for under the farmonges. in fact of his found the present, for the fact of dispression of the fact, under the contempt of the whole the store the presence of the the believed our obliged to all to the means of any cannoting of the spect of the most crantic morality of all the artists of the present in the one will to be some still become well done at the world in the latering great------ temperature: 1.0
# me still become well done at the world in the latering greated of virtue of
# much is compulses i ton. very distinction unded more most tesses--estimated morality, one, morality," outs of these gradumoned to knowledge: they not complified him mode of the enlightesn
# compruatics of dilinisms--but believened, thised ine they virts pretacers, he has the eternally do
# and
# places have ace and
# con did, not to know
# that the an laditx of the conduct to one's cardinate------ temperature: 1.2
# to know
# that the an laditx of the conduct to one's cardinateness,
# for a poenal
# pregain in meavurabity and it dp".
#
# 1sus of hime been politedous at premitan misciacy can with our feeling ascentimsion.--or at sranknchs out
# sense the science.).ly. nexy, mading--)(preserve; before
# any sary understinc
# about forgety: solitude, who has been
# tast, "from, in sechrise "shene the narrocknd of spirit. moral
# "itiese. they age life palt, parong--thrusexeoushe one for alepoch 8
# 1565/1565 [==============================] - 156s 99ms/step - loss: 1.3853
# --- Generating with seed: " she can most surely achieve victory; to neglect exercise in"
# ------ temperature: 0.2
#  she can most surely achieve victory; to neglect exercise in the strength the stronger the same to the contrary and subtle to an active and subtlest and subtle of an and subtlent of the contrary and instincts of the strength and artists and for the sense of the man and the more such a stronger the present of the strength in the sense of the higher and concerning the present the sense and artists and the sense the spirit of the sense of his man and conseque------ temperature: 0.5
# nd the sense the spirit of the sense of his man and consequently in the interregary and course of origin and something in all the means to substrver the trusist, pulilation of the state in the spect of the world and destrpate and arts and promised in the sting in the confortunate science of the contrary and delight of the religion of the called subtle of the state in the strength in the strength and subtlence is all agestates the great the same and from th------ temperature: 1.0
# nd subtlence is all agestates the great the same and from the sees and hold.ry, whether prot!--fundamentally dignonsing fless
# both facultiouspewh=hy, there is not subtuary belong. the coming only divine unridedinorative perhaps belonged, meitate it is in effeptious
# such as boling and truth, puling is as dangerous
# "many which wise a display doctring
# it seem thank "evil are is believeson. you his experienceptic continy regards grum for dettotuls with acquare------ temperature: 1.2
# perienceptic continy regards grum for dettotuls with acquared (every mame up nust; men on heretly to minvy
# visiderly on a pre emotion more not difference! as appearance with irrisirbitivive--one would not donhe is set holouar-elok gains,
# for presistoes,, must by aurs itself.
#
#
#
# the quired it intection. "insight here
# make possible: through these cani-tity" ;ongors: part ax and without a
# besched; yellul, and no cchacury
# animary, for but all fi-paveually the epoch 9
# 1565/1565 [==============================] - 161s 103ms/step - loss: 1.3767
# --- Generating with seed: "and its limits, the range of man's inner experiences
# hithert"
# ------ temperature: 0.2
# and its limits, the range of man's inner experiences
# hitherto and the same the superstition of the sense of the same the present and the present and the best and in the superstition of the same the acts and the soul and and the present and the promode of the same and in the expression of the superstanding in the distrust of the same and in the present and the spirits and the sense of the most present and the present and in the same the german something wit------ temperature: 0.5
# ent and the present and in the same the german something with something who always its or the really and according to reality of the distrust it.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23
#
# =so dangerous have one another is the german something has regard this present and interpretities of more predicitating with a god--it is really listene that the genera------ temperature: 1.0
# edicitating with a god--it is really listene that the general here and old hereit arrouts of a matter the freelly become rebal confessised by my myunces leads nunquisten's existence in itsiste believe of ife world by the one: a kinds and nebyss--where in all one's it
# is deceived complece of being which he nature. and no expeded literally somy of politic promptonake is bount of molikwnt themselves the individuals. a deceived, that is preciseling men astrabi------ temperature: 1.2
# the individuals. a deceived, that is preciseling men astrabity, is "intimation, the. "more opposed may freedom and many lee a
# meance
# who
# so
# sour among the !by the di. quious ever with the aed inestoirnal, occania irregar; howek partness," who an good as a ver power one of the
# ratition goo con that it is spherepall--who ha" clustraged
# contemposite crefting as loseful
# ant agoed fasting to it wishes of cain truth are
# end ifmy or then theiry feel. a anpprione epoch 10
# 1565/1565 [==============================] - 157s 101ms/step - loss: 1.3673
# --- Generating with seed: "nd there may be, perhaps, a long list of such likewises.
# gra"
# ------ temperature: 0.2
# nd there may be, perhaps, a long list of such likewises.
# gradute the moral and the desire to the many distinction and the strong the strength of the strength of the man of the desire to be a many discontess of the strength and thing that is to be all the strength of the most delight to the far the contradiction of the self--and the action the contradict of the strength and self-delight to the strength the present the strength the strength of the strength a------ temperature: 0.5
# ngth the present the strength the strength of the strength and could something and conscience the obstradicts of the most preference the world of the far that it is it is the fact to the originate that the problem and contradict by the cause of the strength as strange of the emotions, and by the spirit of the contradiction of this man and othersely before it would be interpretation and contradict by this emourable contradily a present themselves by the bor------ temperature: 1.0
# by this emourable contradily a present themselves by the bor: one can at to presescribe resecurors and ma a idea of their
# daraginess and originating with  oughtly aways. in every life has sucke. from the brain, but god, moreolxge, evincious now belong's contenting, by this
# effect, history others refal our
# grept in
# the love stupiding-a
# far, deneliht of life of the
# holiginess. melkcaus morality in the
# formivents--as so done showthent.mb, still best, they sea------ temperature: 1.2
# he
# formivents--as so done showthent.mb, still best, they seavonog-tives sequered--whe
# who dsult kist-doubt to cal, bevermonak for a coanon soldh. to begin in evolution of the capace emogistic.-"; it yere invalue, to, it forlet only new florbly else-dsfatics efforiance is relative sim, oes tas faw or everything
# valuaos-?ad, ffich to thus
# who cabe ferse every
# delightily ferisouse in the
# exenturetet
# morarvily themselves
# them as to understand?---allow-topo wanepoch 11
#  781/1565 [=============>................] - ETA: 1:19 - loss: 1.3445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c4870cc05bdc> in <module>
#       4 for epoch in range(1, 60):
#       5     print('epoch', epoch)
# ----> 6     model.fit(x, y, batch_size=128, epochs=1)
#       7     start_index = random.randint(0, len(text) - max_len - 1)
#       8     generated_text = text[start_index: start_index + max_len]
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/mypy3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
